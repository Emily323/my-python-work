# %%
# !pip install jieba
# !pip install wordcloud

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from wordcloud import WordCloud
import jieba

# %%
text = open('C:/Python Work/text.txt','r',encoding="utf-8").read()  
cut_text = ' '.join(jieba.cut(text))
color_mask = imread('C:\Python Work\交作業囉\c.jpg')
cloud = WordCloud(font_path='c:\WINDOWS\FONTS\MSJHL.TTC',
mask=color_mask,
background_color="white",
max_words=50,
max_font_size=32)
word_cloud = cloud.generate(cut_text)
plt.axis('off')
plt.imshow(word_cloud)
plt.show()

# %%
a = open('C:/Python Work/text.txt','r',encoding="utf-8").read()  
b = ' '.join(jieba.cut(text))

c= WordCloud(font_path='c:\WINDOWS\FONTS\MSJHL.TTC',
mask=color_mask,
background_color="white",
max_words=50,
max_font_size=32)
word_cloud = cloud.generate(b)
plt.axis('off')
plt.imshow(word_cloud)
plt.show()

# %%
text_from_file_with_apath = open('C:/Python Work/text.txt','r',encoding="utf-8").read()  
wl_space_split = " ".join(jieba.cut(text_from_file_with_apath, cut_all = True))
my_wordcloud = WordCloud().generate(wl_space_split)
plt.imshow(my_wordcloud)
plt.axis("off")
plt.show()
